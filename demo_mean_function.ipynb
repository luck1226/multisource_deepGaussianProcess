# %%
# %pylab inline
import pylab as pb
pylab.ion()
import GPy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
mf = GPy.core.Mapping(1,1)

#mf2 = GPy.mappings.Linear(1,1)

mf.f = np.sin
mf.update_gradients = lambda a,b: None

X = np.linspace(0,10,50).reshape(-1,1)
Y = np.sin(X) + 0.5*np.cos(3*X) + 0.1*np.random.randn(*X.shape)

k =GPy.kern.RBF(1)
lik = GPy.likelihoods.Gaussian()
m = GPy.core.GP(X, Y, kernel=k, likelihood=lik, mean_function=mf)

# %%
m.optimize()

# %%
m.plot()
# Out:
# {'dataplot': [<matplotlib.collections.PathCollection at 0x7fea5e77f150>],
#  'gpmean': [[<matplotlib.lines.Line2D at 0x7fea5e77f750>]],
#  'gpconfidence': [<matplotlib.collections.PolyCollection at 0x7fea5e77fb90>]}

# %%
mf1 = GPy.mappings.Linear(1,1)

m1 = GPy.core.GP(X, Y, kernel=k, likelihood=lik, mean_function=mf1)

m1.optimize()

# %%
m1.plot()
# Out:
# {'dataplot': [<matplotlib.collections.PathCollection at 0x7fea61fccc50>],
#  'gpmean': [[<matplotlib.lines.Line2D at 0x7fea5e7ab450>]],
#  'gpconfidence': [<matplotlib.collections.PolyCollection at 0x7fea61fda650>]}

# %%
print(m1)
# Out:
# Name : gp
# Objective : -8.27190815139063
# Number of Parameters : 4
# Number of Optimization Parameters : 4
# Updates : True
# Parameters:
#   gp.                      |                value  |  constraints  |  priors
#   linmap.A                 |         [0.01939649]  |               |
#   rbf.variance             |   0.7222798176069438  |      +ve      |
#   rbf.lengthscale          |   0.7416723962606988  |      +ve      |
#   Gaussian_noise.variance  |  0.00931294708026426  |      +ve      |

# %%
print(m)
# Out:
# Name : gp
# Objective : -12.156809261979191
# Number of Parameters : 0
# Number of Optimization Parameters : 0
# Updates : True
# Parameters:
#   gp.  |  value  |  constraints  |  priors
